# %%
import pandas as pd
import numpy as np
import sys

# %%
sys.path.append('../src')

# %%
# from scrape_ecommerce_data import TelegramScraper

# %%
# telegram = TelegramScraper(
#     api_id='23735929',
#     api_hash='36c1864894007dcb935128b3252887a9',
#     channels=['ZemenExpress', 'nevacomputer', 'meneshayeofficial']
# )

# %%
df = pd.read_csv('../data/processed/processed_20250621_001755.csv')

# %%
df
# Out:
#                channel  message_id                       date   views  \
# 0         ZemenExpress        6982  2025-06-18 06:01:10+00:00  2382.0
# 1         ZemenExpress        6981  2025-06-16 12:21:00+00:00  3421.0
# 2         ZemenExpress        6973  2025-06-16 05:11:57+00:00  2826.0
# 3         ZemenExpress        6972  2025-06-16 05:11:26+00:00  2578.0
# 4         ZemenExpress        6970  2025-06-16 05:09:03+00:00  2823.0
# ..                 ...         ...                        ...     ...
# 157  meneshayeofficial         924  2025-02-01 09:30:41+00:00  3020.0
# 158  meneshayeofficial         923  2025-01-31 10:20:06+00:00  2703.0
# 159  meneshayeofficial         922  2025-01-30 15:50:58+00:00  2547.0
# 160  meneshayeofficial         921  2025-01-30 09:03:34+00:00  3068.0
# 161  meneshayeofficial         920  2025-01-28 12:26:16+00:00  2969.0
#
#                                                   text  has_media  \
# ...
